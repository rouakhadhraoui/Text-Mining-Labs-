# %% [markdown]
# <a href="https://colab.research.google.com/github/rouakhadhraoui/Text-Mining-Labs-/blob/main/vader_textblob_pattern_example_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment textblob
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.12/dist-packages (3.3.2)
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2025.10.5)

# %%
# !pip install setuptools wheel
# !pip install beautifulsoup4 lxml feedparser
# !pip install git+https://github.com/clips/pattern.git
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.12/dist-packages (6.0.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.12/dist-packages (from feedparser) (1.0.0)
# Collecting git+https://github.com/clips/pattern.git
#   Cloning https://github.com/clips/pattern.git to /tmp/pip-req-build-v1hufbzv
#   Running command git clone --filter=blob:none --quiet https://github.com/clips/pattern.git /tmp/pip-req-build-v1hufbzv
#   Resolved https://github.com/clips/pattern.git to commit d25511f9ca7ed9356b801d8663b8b5168464e68f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (1.0.0)
# Requirement already satisfied: backports.csv in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (1.0.7)
# Requirement already satisfied: mysqlclient in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (2.2.7)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (5.4.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (6.0.12)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (20250506)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (1.16.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (3.9.1)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (1.2.0)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (18.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from Pattern==3.6) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->Pattern==3.6) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->Pattern==3.6) (4.15.0)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from cherrypy->Pattern==3.6) (11.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from cherrypy->Pattern==3.6) (3.2.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from cherrypy->Pattern==3.6) (10.8.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.12/dist-packages (from cherrypy->Pattern==3.6) (4.0)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.12/dist-packages (from cherrypy->Pattern==3.6) (5.2.1)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.12/dist-packages (from feedparser->Pattern==3.6) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->Pattern==3.6) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->Pattern==3.6) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->Pattern==3.6) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->Pattern==3.6) (4.67.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six->Pattern==3.6) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six->Pattern==3.6) (43.0.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->Pattern==3.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->Pattern==3.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->Pattern==3.6) (2025.10.5)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from cheroot>=8.2.1->cherrypy->Pattern==3.6) (4.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six->Pattern==3.6) (2.0.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.12/dist-packages (from portend>=2.1.1->cherrypy->Pattern==3.6) (5.8.1)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.12/dist-packages (from jaraco.collections->cherrypy->Pattern==3.6) (4.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from zc.lockfile->cherrypy->Pattern==3.6) (75.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->Pattern==3.6) (2.23)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->Pattern==3.6) (2.9.0.post0)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.12/dist-packages (from jaraco.text->jaraco.collections->cherrypy->Pattern==3.6) (6.0.1)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.12/dist-packages (from jaraco.text->jaraco.collections->cherrypy->Pattern==3.6) (2.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->tempora>=1.8->portend>=2.1.1->cherrypy->Pattern==3.6) (1.17.0)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from pattern.en import sentiment

# Sample text for sentiment analysis
text = "I love this product! It's amazing."
text1= "The service was slow and the food was cold."
text2="I really hate this. It’s terrible and disappointing."
text3="It is a day like any other."

# Vader Sentiment Analysis
vader_analyzer = SentimentIntensityAnalyzer()
vader_scores = vader_analyzer.polarity_scores(text)
vader_compound_score = vader_scores['compound']
vader_sentiment = 'positive' if vader_compound_score >= 0 else 'negative'

print(f"Vader Sentiment: {vader_sentiment} (Compound Score: {vader_compound_score})")

# TextBlob Sentiment Analysis
text_blob_analysis = TextBlob(text)
text_blob_polarity = text_blob_analysis.sentiment.polarity
text_blob_sentiment = 'positive' if text_blob_polarity > 0 else 'negative' if text_blob_polarity < 0 else 'neutral'

print(f"TextBlob Sentiment: {text_blob_sentiment} (Polarity: {text_blob_polarity})")

# Pattern Sentiment Analysis
pattern_sentiment = sentiment(text)
pattern_polarity = pattern_sentiment[0]
pattern_subjectivity = pattern_sentiment[1]
pattern_sentiment_label = 'positive' if pattern_polarity > 0 else 'negative' if pattern_polarity < 0 else 'neutral'

print(f"Pattern Sentiment: {pattern_sentiment_label} (Polarity: {pattern_polarity}, Subjectivity: {pattern_subjectivity})")
# Out:
# Vader Sentiment: positive (Compound Score: 0.8516)
# TextBlob Sentiment: positive (Polarity: 0.6125)
# Pattern Sentiment: positive (Polarity: 0.6125, Subjectivity: 0.75)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from pattern.en import sentiment

# Sample text for sentiment analysis
text = "I love this product! It's amazing."
text1= "The service was slow and the food was cold."
text2="I really hate this. It’s terrible and disappointing."
text3="It is a day like any other."

# Vader Sentiment Analysis
vader_analyzer = SentimentIntensityAnalyzer()
vader_scores = vader_analyzer.polarity_scores(text1)
vader_compound_score = vader_scores['compound']
vader_sentiment = 'positive' if vader_compound_score >= 0 else 'negative'

print(f"Vader Sentiment: {vader_sentiment} (Compound Score: {vader_compound_score})")

# TextBlob Sentiment Analysis
text_blob_analysis = TextBlob(text1)
text_blob_polarity = text_blob_analysis.sentiment.polarity
text_blob_sentiment = 'positive' if text_blob_polarity > 0 else 'negative' if text_blob_polarity < 0 else 'neutral'

print(f"TextBlob Sentiment: {text_blob_sentiment} (Polarity: {text_blob_polarity})")

# Pattern Sentiment Analysis
pattern_sentiment = sentiment(text1)
pattern_polarity = pattern_sentiment[0]
pattern_subjectivity = pattern_sentiment[1]
pattern_sentiment_label = 'positive' if pattern_polarity > 0 else 'negative' if pattern_polarity < 0 else 'neutral'

print(f"Pattern Sentiment: {pattern_sentiment_label} (Polarity: {pattern_polarity}, Subjectivity: {pattern_subjectivity})")
# Out:
# Vader Sentiment: positive (Compound Score: 0.0)
# TextBlob Sentiment: negative (Polarity: -0.45)
# Pattern Sentiment: negative (Polarity: -0.45, Subjectivity: 0.7)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from pattern.en import sentiment

# Sample text for sentiment analysis
text = "I love this product! It's amazing."
text1= "The service was slow and the food was cold."
text2="I really hate this. It’s terrible and disappointing."
text3="It is a day like any other."

# Vader Sentiment Analysis
vader_analyzer = SentimentIntensityAnalyzer()
vader_scores = vader_analyzer.polarity_scores(text2)
vader_compound_score = vader_scores['compound']
vader_sentiment = 'positive' if vader_compound_score >= 0 else 'negative'

print(f"Vader Sentiment: {vader_sentiment} (Compound Score: {vader_compound_score})")

# TextBlob Sentiment Analysis
text_blob_analysis = TextBlob(text2)
text_blob_polarity = text_blob_analysis.sentiment.polarity
text_blob_sentiment = 'positive' if text_blob_polarity > 0 else 'negative' if text_blob_polarity < 0 else 'neutral'

print(f"TextBlob Sentiment: {text_blob_sentiment} (Polarity: {text_blob_polarity})")

# Pattern Sentiment Analysis
pattern_sentiment = sentiment(text2)
pattern_polarity = pattern_sentiment[0]
pattern_subjectivity = pattern_sentiment[1]
pattern_sentiment_label = 'positive' if pattern_polarity > 0 else 'negative' if pattern_polarity < 0 else 'neutral'

print(f"Pattern Sentiment: {pattern_sentiment_label} (Polarity: {pattern_polarity}, Subjectivity: {pattern_subjectivity})")
# Out:
# Vader Sentiment: negative (Compound Score: -0.8832)
# TextBlob Sentiment: negative (Polarity: -0.7999999999999999)
# Pattern Sentiment: negative (Polarity: -0.7999999999999999, Subjectivity: 0.8666666666666666)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from pattern.en import sentiment

# Sample text for sentiment analysis
text = "I love this product! It's amazing."
text1= "The service was slow and the food was cold."
text2="I really hate this. It’s terrible and disappointing."
text3="It is a day like any other."

# Vader Sentiment Analysis
vader_analyzer = SentimentIntensityAnalyzer()
vader_scores = vader_analyzer.polarity_scores(text3)
vader_compound_score = vader_scores['compound']
vader_sentiment = 'positive' if vader_compound_score >= 0 else 'negative'

print(f"Vader Sentiment: {vader_sentiment} (Compound Score: {vader_compound_score})")

# TextBlob Sentiment Analysis
text_blob_analysis = TextBlob(text3)
text_blob_polarity = text_blob_analysis.sentiment.polarity
text_blob_sentiment = 'positive' if text_blob_polarity > 0 else 'negative' if text_blob_polarity < 0 else 'neutral'

print(f"TextBlob Sentiment: {text_blob_sentiment} (Polarity: {text_blob_polarity})")

# Pattern Sentiment Analysis
pattern_sentiment = sentiment(text3)
pattern_polarity = pattern_sentiment[0]
pattern_subjectivity = pattern_sentiment[1]
pattern_sentiment_label = 'positive' if pattern_polarity > 0 else 'negative' if pattern_polarity < 0 else 'neutral'

print(f"Pattern Sentiment: {pattern_sentiment_label} (Polarity: {pattern_polarity}, Subjectivity: {pattern_subjectivity})")
# Out:
# Vader Sentiment: positive (Compound Score: 0.3612)
# TextBlob Sentiment: negative (Polarity: -0.125)
# Pattern Sentiment: negative (Polarity: -0.125, Subjectivity: 0.375)
